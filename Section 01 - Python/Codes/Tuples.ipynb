# %% [markdown]
# <h1 style = "color : Brown">Tuples</h1>
#
#    - Tuples are ordered sequence of mixed data types
#    - Tuples are written in comma separated elements within parenthesis

# %%
t = (1,2,3,4)

# %%
t2 = 1,2,3,4

# %%
t1 = [1,2,3,4]

# %%
type(t2)
# Out:
# tuple

# %%
t = ('hello', 5, 5.5
t
# Out:
# ('hello', 5, 5.5)

# %%
len(t)
# Out:
# 3

# %%
nested_tup = (1, 2, 3, (4,5))

# %%
len(nested_tup)
# Out:
# 4

# %%
t1 = ('hello', 5, 5.5, [2,3,4])

# %%
len(t1)
# Out:
# 4

# %%
type(t1[3])
# Out:
# list

# %%
var = t1[3]
type(var)
# Out:
# list

# %%
var
# Out:
# [2, 3, 4]

# %%
var[1]
# Out:
# 3

# %%
t1 = ('hello', 5, 5.5, [2,3,4])

# %%
t1[3]
# Out:
# [2, 3, 4]

# %%
t1[3][1]
# Out:
# 3

# %%
t1[3][1]
# Out:
# 3

# %%
len(t1)
# Out:
# 4

# %% [markdown]
#     Tuples can be defined in various ways

# %%
t1 = 1,2,3,4,5
print(t1)
print(type(t1))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
t1 = 1.2,
type(t1)
# Out:
# tuple

# %%
t1 = 1.2
type(t1)
# Out:
# float

# %%
len(t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-13f56e1889ef> in <cell line: 0>()
# ----> 1 len(t1)
#
# TypeError: object of type 'float' has no len()

# %%
t2 = (2,)

# %%
type(t2)
# Out:
# tuple

# %%
t3 = 2,

# %%
type(t3)
# Out:
# tuple

# %%
#single value tuple

t2 = 1,
print(t2)
# Out:
# (1,)

# %%
t3 = (1,)
print(t3)
# Out:
# (1,)

# %%
#This is not a tuple

t4 = 1
t5 = (1)

# %%
type(t5)
# Out:
# int

# %% [markdown]
# #### Indexing in tuple

# %%
t = ("Mumbai", 10, "Python", 100)

# %%
len(t)
# Out:
# 4

# %%
t[2:]
# Out:
# ('Python', 100)

# %%
t = ("Mumbai", 10, "Python", 100, "Delhi")

# %%
t[2:4]
# Out:
# ('Python', 100)

# %%
str1 = "HELLO WORLD"
str1[6:]
# Out:
# 'WORLD'

# %%
#gives the element at index location 0 i.e. 1st element

print(t[0])

#gives the element at index location 1

print(t[1])
# Out:
# Mumbai
# 10

# %% [markdown]
# #### Slicing

# %%
#slicing first 2 elements from t

t = ("Mumbai", 10, "Python", 100)

t[0:2]
# Out:
# ('Mumbai', 10)

# %%
#slicing last  2 elements from t

t[2:]
# Out:
# ('Python', 100)

# %%
t[2:]
# Out:
# ('Python', 100)

# %%
t[-2:]
# Out:
# ('Python', 100)

# %%
#slicing last 2 elements from t

t[-2:]
# Out:
# ('Python', 100)

# %%
#find the number of elements in a tuple

len(t)
# Out:
# 4

# %% [markdown]
# #### Concatenation

# %%
list1 = [1,2,3,4]
list2 = [11,12,13,14]

list3 = list1 + list2
print(list3)
# Out:
# [1, 2, 3, 4, 11, 12, 13, 14]

# %%
tup1 = ("welcome", "to", "today's")
tup2 = ("class", "on", "python")

# %%
tup3 = tup1 + tup2

# %%
tup3
# Out:
# ('welcome', 'to', "today's", 'class', 'on', 'python')

# %% [markdown]
# #### min, max, sum functions

# %%
l1 = [2,4,6,8]
sum(l1)
# Out:
# 20

# %%
min(l1)
# Out:
# 2

# %%
t = (2,4,6,8)
sum(t)
# Out:
# 20

# %%
t = (2,4,6,'hello')
sum(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-509fb2708f06> in <cell line: 0>()
#       1 t = (2,4,6,'hello')
# ----> 2 sum(t)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
t = (2,4,6,8)
min(t)
# Out:
# 2

# %%
t = (2,4,6,8)
max(t)
# Out:
# 8

# %%
t = (5.5, 4.2, 5, 9)
max(t)
# Out:
# 9

# %%
tuple1 = (1,2,3,4,"hello", "world", (1,2,3))

# %%
len(tuple1)
# Out:
# 7

# %%
tuple1[6][1]
# Out:
# 2

# %%
tuple1[-1][1]
# Out:
# 2

# %%
tuple1[-1][-2]
# Out:
# 2

# %%
tuple1[6][-2]
# Out:
# 2

# %%
tuple2 = (1,2,3)
tuple2[1]
# Out:
# 2

# %%
tuple1[6][1]
# Out:
# 2

# %% [markdown]
# #### Immutability

# %%
list_1 = ["Bio", "Chem", "Phy", "Math"]

# %%
list_1[0] = "Comp Sc"
print(list_1)
# Out:
# ['Comp Sc', 'Chem', 'Phy', 'Math']

# %%
tuple1_1 = ("Bio", "Chem", "Phy", "Math")

# %%
tuple1_1[0] = "Comp Sc"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-af83f54a5575> in <module>
# ----> 1 tuple1_1[0] = "Comp Sc"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = ("Hello!!", "Welcome" , 5, 10, "world", "of", "Analytics!!")

# %%
t[3]
# Out:
# 10

# %%
t[2] = "to"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-bae901a244a5> in <cell line: 0>()
# ----> 1 t[2] = "to"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = ("Hello!!", "Welcome" , 5, 10, "world", "of", "Analytics!!")

# %%
t[0:2]
# Out:
# ('Hello!!', 'Welcome')

# %%
t[-3:]
# Out:
# ('world', 'of', 'Analytics!!')

# %%
new_tuple = t[0:2] + ("to", "the") + t[-3:]

# %%
new_tuple
# Out:
# ('Hello!!', 'Welcome', 'to', 'the', 'world', 'of', 'Analytics!!')

# %%
len(new_tuple)
# Out:
# 7

# %%
#How to update the 2nd and 3rd element

new_tuple = t[0:2] + ("to", "the",) + t[-3:]

# %%
new_tuple
# Out:
# ('Hello!!', 'Welcome', 'to', 'the', 'world', 'of', 'Analytics!!')

# %%
#QUESTION

t = ("disco", 12, 4.5)
t[0][2]
# Out:
# 's'

# %%
t[0][-3]
# Out:
# 's'

# %%
t[-3][-3]
# Out:
# 's'

# %%
t[-3][2]
# Out:
# 's'

# %% [markdown]
# #### Sorting a tuple

# %%
t = (2,3,8,5,4,1)
new_var = sorted(t)
print(new_var)
print(type(new_var))
# Out:
# [1, 2, 3, 4, 5, 8]
# <class 'list'>

# %%
new_list = sorted(t)
new_list
# Out:
# [1, 2, 3, 4, 5, 8]

# %%
# Type casting

t2 = tuple(new_list)

# %%
t2
# Out:
# (1, 2, 3, 4, 5, 8)

# %%
x = sorted(t)

tuple(x)
# Out:
# (1, 2, 3, 4, 5, 8)

# %%
# Nested tuples

t = (1,5,"Hello","World", ("Java", "Python"))

# %%
t[4][0]
# Out:
# 'Java'

# %%
t[4][-2]
# Out:
# 'Java'

# %%
t[-1][-2]
# Out:
# 'Java'

# %%
t[-1][0]
# Out:
# 'Java'

# %%
#How to access Java ????

# %%
#QUESTION 1

t = (1, 2, 4, 3)

#What will be the output of t[4]

#QUESTION 2

#Which of the following declarations can be used to create a Python tuple?
#(More than one option may be correct.)

x = ('2')
x = 1,2,
x = ((1,2,3), 4,5)
x = (Hello,'2','3')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-1f8ff983b929> in <cell line: 0>()
#      13 x = 1,2,
#      14 x = ((1,2,3), 4,5)
# ---> 15 x = (Hello,'2','3')
#
# NameError: name 'Hello' is not defined

# %%
x = (Hello,'2','3')
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-c6ae7fac92a9> in <module>
# ----> 1 x = (Hello,'2','3')
#       2 type(x)
#
# NameError: name 'Hello' is not defined

# %%
t = (1, 2, 4, 3)
t[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-106-bf43bda218bd> in <module>
#       1 t = (1, 2, 4, 3)
# ----> 2 t[4]
#
# IndexError: tuple index out of range

# %%
x = ('2')
type(x)
# Out:
# str

# %%
x = 1,2,
type(x)
# Out:
# tuple

# %%
x = ((1,2,3), 4,5)
type(x)
# Out:
# tuple

# %%
x = (Hello,'2','3')
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-c6ae7fac92a9> in <cell line: 0>()
# ----> 1 x = (Hello,'2','3')
#       2 type(x)
#
# NameError: name 'Hello' is not defined

# %%
tuple2 = ("India", "Delhi", 5, 10, ["Rajkot", "Chennai"])

# %%
tuple1 = (1,2,55,4,19,22)

# %%
list1 = sorted(tuple1, reverse=True)
tuple2 = tuple(list1)
print(tuple2)
# Out:
# (55, 22, 19, 4, 2, 1)

# %%
tuple3 = (1,)
type(tuple3)

# %% [markdown]
# ![image.png](attachment:image.png)
