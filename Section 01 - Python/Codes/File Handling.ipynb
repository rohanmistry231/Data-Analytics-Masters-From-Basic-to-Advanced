# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## File Handling

# %% [markdown]
# #### Reading a file

# %%
file = open('test.txt', 'r')


for line in file:
    print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-a9ff87af22aa> in <cell line: 0>()
# ----> 1 file = open('test.txt', 'r')
#       2
#       3
#       4 for line in file:
#       5     print(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
file = open('test.txt', 'r')
print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-fef120a6f1fe> in <cell line: 0>()
# ----> 1 file = open('test.txt', 'r')
#       2 print(file.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
file = open('test.txt', 'r')
print(file.read(10))
# Out:
# Hello Worl

# %% [markdown]
# hello friend

# %%
file = open('test.txt', 'r')
print(file.readline())
# Out:
# Hello World

# %%
file = open('test.txt', 'r')
print(file.readline(50))
# Out:
# Hello World

# %%
file = open('test.txt', 'r')
print(file.read(50))
# Out:
# Hello World
# My name is Satyajit Pattnaik
# Welcome t

# %% [markdown]
# #### Writing a file

# %%
file = open('test.txt', 'w')
file.write("This is a write operation")
file.write("Hello!! Thanks for joining this program")
# Out:
# 39

# %%
print(file.read())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-28-094f07845ae3> in <module>
# ----> 1 print(file.read())
#
# UnsupportedOperation: not readable

# %%
file = open('test.txt', 'w')
file.write("This is a write operation")
file.write("Hello!! Thanks for joining this program")
file.close()

# %%
file = open('test.txt', 'r')
print(file.read())
# Out:
# This is a write operationHello!! Thanks for joining this program

# %% [markdown]
# #### Append operation

# %%
with open('test.txt', 'a') as file:
    file.write("This is a write operation")

# %%
file = open('test.txt', 'r')
for line in file:
    print(line)
# Out:
# This is a write operationHello!! Thanks for joining this programThis is a write operation

# %% [markdown]
# #### \n operation

# %%
file = open('test.txt', 'w')
file.write("This is a write operation")
file.write("\n")
file.write("Hello!! Thanks for joining this program")
file.close()

# %%
file = open('test.txt', 'r')
print(file.read())
# Out:
# This is a write operation
# Hello!! Thanks for joining this program

# %%
file = open('test.txt', 'r')
for line in file:
    print(line)
# Out:
# This is a write operation
#
# Hello!! Thanks for joining this programThis is a write operation
#
# This is a write operation

# %%
with open('test.txt', 'a+') as file:
    file.write("\n")
    file.write("This is a write operation")

# %%
file = open('test.txt', 'r')
for line in file:
    print(line)
# Out:
# This is a write operation
#
# Hello!! Thanks for joining this programThis is a write operation
#
# This is a write operation
#
# This is a write operation

# %% [markdown]
# #### Reading files using Pandas library

# %%
import pandas as pd

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
