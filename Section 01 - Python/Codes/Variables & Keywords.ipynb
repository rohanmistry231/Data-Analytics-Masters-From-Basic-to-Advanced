# %% [markdown]
# <h1 style = "color : Brown">Variables & Keywords</h1>

# %% [markdown]
# A Python variable is a reserved memory location to store values. In other words, a variable in a python program gives data to the computer for processing.

# %%
my_age = 30

# %%
print(my_age)
# Out:
# 32

# %%
type(my_age)
# Out:
# int

# %%
my_name = 'Satyajit Pattnaik'

# %%
type(my_name)
# Out:
# str

# %%
a='hello world'

# %%
type(a)
# Out:
# str

# %%
my_age = 31

# %%
print(my_age)
# Out:
# 31

# %%
score = 89.4
score
# Out:
# 89.4

# %%
type(score)
# Out:
# float

# %%
var = "Hello world, welcome to the class"

# %%
type(var)
# Out:
# str

# %%
var = 10

# %%
type(var)
# Out:
# int

# %%
string_var = "Hello world, welcome to the class"

# %%
print(string_var)
# Out:
# Hello world, welcome to the class

# %%
type(string_var)
# Out:
# str

# %%
a = 10.5
print(type(a))
# Out:
# <class 'float'>

# %%
a = 10.5
print(type(a))
# Out:
# <class 'float'>

# %%
a = "10.5"
type(a)
# Out:
# str

# %%
a = '10.5'
print(a)
print(type(a))
# Out:
# 10.5
# <class 'str'>

# %%
a='True'
print(type(a))
print(a)
# Out:
# <class 'str'>
# True

# %%
a=True
print(type(a))
print(a)
# Out:
# <class 'bool'>
# True

# %%
bool_var = "True"
print(bool_var)
print(type(bool_var))
# Out:
# True
# <class 'str'>

# %%
bool_var = True
print(bool_var)
print(type(bool_var))
# Out:
# True
# <class 'bool'>

# %%
a5 = 10

# %%
a5
# Out:
# 10

# %%
5a = 10
# Out:
#   File "<ipython-input-31-62c1943fa328>", line 1
#     5a = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
a=10
A=15

print(a)
print(A)
# Out:
# 10
# 15

# %%
name=2
Name=4

# %%
var = 10

# %%
float_var = 10.1

# %%
type(var)
# Out:
# int

# %%
type(float_var)
# Out:
# float

# %%
string1 = 'hello'
print(string1)
# Out:
# hello

# %%
string1
# Out:
# 'hello'

# %%
string2 = "hello 123 world"
print(string2)
# Out:
# hello 123 world

# %%
1new_var = 10
# Out:
#   File "<ipython-input-41-e637834d698f>", line 1
#     1new_var = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
new_var = 10

# %%
print(new_var)
# Out:
# 10

# %%
name = 2
Name = 4
print(name)
print(Name)
# Out:
# 2
# 4

# %%
a=4
b=5
c=a+b
print(c)
# Out:
# 9

# %%
a=14
b=15
c=a+b
print(c)
# Out:
# 29

# %%
def sum_function(a,b):
    c = a+b
    return c

# %%
sum_function(5,10)
# Out:
# 15

# %%
sum_function(15,20)
# Out:
# 35

# %%
def sum_fun(a,b):
    c=a+b
    return c

sum_fun(5,6)
# Out:
# 11

# %%
def func_sum(a,b):
    c=a+b
    return c


func_sum(4,5)
# Out:
# 9

# %%
func_sum(14,55)
# Out:
# 69

# %%
1name=5
# Out:
#   File "<ipython-input-52-bcd6827c9a66>", line 1
#     1name=5
#     ^
# SyntaxError: invalid decimal literal

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
type = 10

# %%
print(type)
# Out:
# 10

# %%
a = 10.1

# %%
type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-b152ec05ccbc> in <cell line: 0>()
# ----> 1 type(a)
#
# TypeError: 'int' object is not callable

# %%
welcome_string = "Welcome to the Python course"

# %%
print(welcome_string)
# Out:
# Welcome to the Python course

# %%
type(welcome_string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-2845b731b1dd> in <cell line: 0>()
# ----> 1 type(welcome_string)
#
# TypeError: 'int' object is not callable

# %%
a = 10
b = 5
c = a+b
print(c)
# Out:
# 15

# %%
def sum_function(a,b):
    c=a+b
    return c

# %%
sum_function(5,6)
# Out:
# 11

# %%
boolean_var = 'True'

# %%
type(boolean_var)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-575ebe0903ca> in <cell line: 0>()
# ----> 1 type(boolean_var)
#
# TypeError: 'int' object is not callable

# %%
boolean_var = True

# %%
type(boolean_var)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-575ebe0903ca> in <cell line: 0>()
# ----> 1 type(boolean_var)
#
# TypeError: 'int' object is not callable

# %%
name = "satyajit pattnaik"
age = 31
gender = 'male'
address = 'hong kong'

# %%
#type() --> data type of the variable

type(age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-31a383dab402> in <cell line: 0>()
#       1 #type() --> data type of the variable
#       2
# ----> 3 type(age)
#
# TypeError: 'int' object is not callable

# %%
continue, break def, print, type, len, in, import None, break, else, if

# %%
A= (3,2,4,1,5)
B = tuple(sorted(A))
B
# Out:
# (1, 2, 3, 4, 5)

# %%
List1=[1,2,3,4,5]
List2=List1[:]
List2[0],List2[-1] = List1[-1],List1[0]
List1

def swap_list(List1):
    List2=List1[:]
    List2[0],List2[-1] = List1[-1],List1[0]
    return List2

    List1=[1,2,3,4,5]
    swap_list(List1)
